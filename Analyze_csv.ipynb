# %%
import sys
extra_paths = ["/Users/brownd/mu2e/pyana/RefAna","/Users/brownd/mu2e/pyana/TensionBox"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /Users/brownd/mu2e/pyana/RefAna
# adding path /Users/brownd/mu2e/pyana/TensionBox
# ['/Users/brownd/mu2e/pyana/TensionBox', '/Users/brownd/mu2e/pyana/awkward-behaviors', '/Users/brownd/mu2e/pyana/RefAna', '/Users/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/Users/brownd/miniconda3/envs/RefAna/lib/python3.13', '/Users/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/Users/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages']

# %%
import Analyze_csv

# %%
wa01 = Analyze_csv.Analyze_csv("/Users/brownd/Downloads/plucked wire - Center Pluck.csv",5100,12000)
wa02 = Analyze_csv.Analyze_csv("/Users/brownd/Downloads/plucked wire - End Pluck.csv",5100,12000)

# %%
wa01.plot()
# Out:
# Fundamental frequency = 216.01 Hz
# Wire tension = 76.12 grams

# %%
wa02.plot()
# Out:
# Fundamental frequency = 214.59 Hz
# Wire tension = 75.13 grams
