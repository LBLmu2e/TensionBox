# %% [markdown]
# ##### import sys
# extra_paths = ["/Users/brownd/mu2e/pyana/RefAna","/Users/brownd/mu2e/pyana/TensionBox"]
# for extra_path in extra_paths:
#     print("adding path",extra_path)
#     if extra_path not in sys.path:
#         sys.path.append(extra_path)
# print(sys.path)
# #%pip install serial
# #%pip install serial.tools

# %%
import LoopTension

# %%
lt = LoopTension.LoopTension(0.864)
# Out:
# Initializing tension measurement for wire length 0.864
# Arduino Due at /dev/cu.usbmodem3101
# Initial digitization frequency = 3333.33
# initialized

# %%
lt.loop(10)
# Out:
# Looping over 10 pulses
# Initial frequency = 166.5 Hz, pulse width = 0.003002 seconds
# b'16333\r\n'
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 156.8 Hz, corresponding to a tension of 70.9 gm
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 157.1 Hz, corresponding to a tension of 71.2 gm
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 157.2 Hz, corresponding to a tension of 71.3 gm
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 157.5 Hz, corresponding to a tension of 71.5 gm
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 156.9 Hz, corresponding to a tension of 71.0 gm
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 157.3 Hz, corresponding to a tension of 71.4 gm
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 156.9 Hz, corresponding to a tension of 71.0 gm
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 157.2 Hz, corresponding to a tension of 71.3 gm
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 157.0 Hz, corresponding to a tension of 71.1 gm
# Elapsed time = 0.08841 seconds
# Measured digitization frequency = 4524.17
# Measured fundamental frequency 157.2 Hz, corresponding to a tension of 71.2 gm

# %%
lt.plotWaveform()
