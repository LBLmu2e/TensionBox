# %% [markdown]
# ##### import sys
# extra_paths = ["/Users/brownd/mu2e/pyana/RefAna","/Users/brownd/mu2e/pyana/TensionBox"]
# for extra_path in extra_paths:
#     print("adding path",extra_path)
#     if extra_path not in sys.path:
#         sys.path.append(extra_path)
# print(sys.path)
# #%pip install serial
# #%pip install serial.tools

# %%
import LoopTension

# %%
lt = LoopTension.LoopTension(0.65)
# Out:
# Arduino Due at /dev/cu.usbmodem3101
# initialized

# %%
lt.loop(3)
# Out:
# Looping over 3 pulses
# Initial frequency = 417.1 Hz, pulse width = 0.001199 seconds
# b'Using a pulse of width (in microseconds): 1198\r\n'
# Measured fundamental frequency 201.1 Hz, corresponding to a tension of 66.0 gm
# Measured fundamental frequency 201.1 Hz, corresponding to a tension of 66.0 gm
# Measured fundamental frequency 201.1 Hz, corresponding to a tension of 66.0 gm

# %%
lt.plot()
