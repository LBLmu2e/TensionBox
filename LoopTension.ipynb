# %% [markdown]
# ##### import sys
# extra_paths = ["/Users/brownd/mu2e/pyana/RefAna","/Users/brownd/mu2e/pyana/TensionBox"]
# for extra_path in extra_paths:
#     print("adding path",extra_path)
#     if extra_path not in sys.path:
#         sys.path.append(extra_path)
# print(sys.path)
# #%pip install serial
# #%pip install serial.tools

# %%
import LoopTension

# %%
lt = LoopTension.LoopTension(0.63)
# Out:
# Initializing tension measurement for wire length 0.63
# Arduino Due at /dev/cu.usbmodem1101
# Initial digitization frequency = 3333.33

# %%
lt.printTension(10)
# Out:
# Printing tension in a Loopg over 10 pulses
# Initial frequency = 230.6 Hz, pulse width = 0.002168 seconds
# b'775\r\n'
# Measured fundamental frequency 232.4 Hz, corresponding to a tension of 81.2 gm
# Measured fundamental frequency 232.3 Hz, corresponding to a tension of 81.2 gm
# Measured fundamental frequency 232.3 Hz, corresponding to a tension of 81.2 gm
# Measured fundamental frequency 232.3 Hz, corresponding to a tension of 81.2 gm
# Measured fundamental frequency 232.3 Hz, corresponding to a tension of 81.2 gm
# Measured fundamental frequency 232.3 Hz, corresponding to a tension of 81.2 gm
# Measured fundamental frequency 232.3 Hz, corresponding to a tension of 81.2 gm
# Measured fundamental frequency 232.3 Hz, corresponding to a tension of 81.2 gm
# Measured fundamental frequency 232.3 Hz, corresponding to a tension of 81.2 gm
# Measured fundamental frequency 232.3 Hz, corresponding to a tension of 81.2 gm

# %%
lt.plotWaveform()

# %%
#lt.plotTension()
